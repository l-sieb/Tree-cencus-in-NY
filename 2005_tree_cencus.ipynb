# %%
import pandas as pd 

pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
dtypes_37 = {'37':'int64'}
df = pd.read_csv(r'2005_Street_Tree_Census.csv', encoding='UTF-8', delimiter=',', dtype=dtypes_37)
print(df.head())
# Out:
# C:\Users\leasi\AppData\Local\Temp\ipykernel_38860\3767500029.py:2: DtypeWarning: Columns (37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'2005_Street_Tree_Census.csv', encoding='UTF-8', delimiter=',', dtype=dtypes_37)
#    OBJECTID  cen_year  tree_dbh             address tree_loc        pit_type  \
# 0    592373      2005         6      1139 57 STREET    Front    Sidewalk Pit
# 1    592374      2005         6  2220 BERGEN AVENUE   Across    Sidewalk Pit
# 2    592375      2005        13  2360 BERGEN AVENUE    Front  Continuous Pit
# 3    592376      2005        13  2254 BERGEN AVENUE   Across    Sidewalk Pit
# 4    592377      2005        15  2332 BERGEN AVENUE   Across    Sidewalk Pit
#
#   soil_lvl status                               spc_latin  \
# 0    Level   Good                        PYRUS CALLERYANA
# 1    Level   Good                     PLATANUS ACERIFOLIA
# 2    Level   Good  ACER PLATANOIDES          CRIMSON KING
# ...

# %%
df.dtypes
# Out:
# OBJECTID          int64
# cen_year          int64
# tree_dbh          int64
# address          object
# tree_loc         object
# pit_type         object
# soil_lvl         object
# status           object
# spc_latin        object
# spc_common       object
# vert_other       object
# vert_pgrd        object
# vert_tgrd        object
# vert_wall        object
# horz_blck        object
# horz_grate       object
# horz_plant       object
# horz_other       object
# sidw_crack       object
# sidw_raise       object
# wire_htap        object
# wire_prime       object
# wire_2nd         object
# wire_other       object
# inf_canopy       object
# inf_guard        object
# inf_wires        object
# inf_paving       object
# inf_outlet       object
# inf_shoes        object
# inf_lights       object
# inf_other        object
# trunk_dmg        object
# zipcode           int64
# zip_city         object
# cb_num            int64
# borocode          int64
# boroname         object
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'cen_year', 'tree_dbh', 'address', 'tree_loc', 'pit_type',
#        'soil_lvl', 'status', 'spc_latin', 'spc_common', 'vert_other',
#        'vert_pgrd', 'vert_tgrd', 'vert_wall', 'horz_blck', 'horz_grate',
#        'horz_plant', 'horz_other', 'sidw_crack', 'sidw_raise', 'wire_htap',
#        'wire_prime', 'wire_2nd', 'wire_other', 'inf_canopy', 'inf_guard',
#        'inf_wires', 'inf_paving', 'inf_outlet', 'inf_shoes', 'inf_lights',
#        'inf_other', 'trunk_dmg', 'zipcode', 'zip_city', 'cb_num', 'borocode',
#        'boroname', 'cncldist', 'st_assem', 'st_senate', 'nta', 'nta_name',
#        'boro_ct', 'state', 'latitude', 'longitude', 'x_sp', 'y_sp',
#        'objectid_1', 'census tract', 'bin', 'bbl', 'Location 1'],
#       dtype='object')

# %%
tree_subset = df[['OBJECTID', 'cen_year', 'tree_dbh', 'address', 'tree_loc', 'pit_type',
       'soil_lvl', 'status', 'spc_latin', 'spc_common', 'vert_other',
       'vert_pgrd', 'vert_tgrd', 'vert_wall', 'horz_blck', 'horz_grate',
       'horz_plant', 'horz_other', 'sidw_crack', 'sidw_raise', 'wire_htap',
       'wire_prime', 'wire_2nd', 'wire_other', 'inf_canopy', 'inf_guard',
       'inf_wires', 'inf_paving', 'inf_outlet', 'inf_shoes', 'inf_lights',
       'inf_other', 'trunk_dmg', 'zipcode', 'zip_city', 'cb_num',
       'boroname', 'cncldist', 'st_assem', 'st_senate', 'nta', 'nta_name',
       'boro_ct', 'latitude', 'longitude', 'objectid_1']]
tree_subset.head()
# Out:
#    OBJECTID  cen_year  tree_dbh             address tree_loc        pit_type  \
# 0    592373      2005         6      1139 57 STREET    Front    Sidewalk Pit
# 1    592374      2005         6  2220 BERGEN AVENUE   Across    Sidewalk Pit
# 2    592375      2005        13  2360 BERGEN AVENUE    Front  Continuous Pit
# 3    592376      2005        13  2254 BERGEN AVENUE   Across    Sidewalk Pit
# 4    592377      2005        15  2332 BERGEN AVENUE   Across    Sidewalk Pit
#
#   soil_lvl status                               spc_latin  \
# 0    Level   Good                        PYRUS CALLERYANA
# 1    Level   Good                     PLATANUS ACERIFOLIA
# 2    Level   Good  ACER PLATANOIDES          CRIMSON KING
# 3    Level   Good                     PLATANUS ACERIFOLIA
# 4    Level   Good                     PLATANUS ACERIFOLIA
#
#              spc_common vert_other vert_pgrd vert_tgrd vert_wall horz_blck  \
# ...

# %%
# Look at the missing values 

tree_subset.isna().sum()
# Out:
# OBJECTID           0
# cen_year           0
# tree_dbh           0
# address            0
# tree_loc           0
# pit_type           0
# soil_lvl           0
# status             0
# spc_latin          0
# spc_common         0
# vert_other         0
# vert_pgrd          0
# vert_tgrd          0
# vert_wall          0
# horz_blck          0
# horz_grate         0
# horz_plant         0
# horz_other         0
# sidw_crack         0
# sidw_raise         0
# wire_htap          0
# wire_prime         0
# wire_2nd           0
# wire_other         0
# inf_canopy         0
# inf_guard          0
# inf_wires          0
# inf_paving         0
# inf_outlet         0
# inf_shoes          0
# inf_lights         0
# inf_other          0
# trunk_dmg          0
# zipcode            0
# zip_city        8911
# cb_num             0
# boroname           0
# cncldist           0
# st_assem           0
# st_senate          0
# nta                0
# nta_name           0
# boro_ct       105310
# ...

# %%
tree_subset['zip_city'].value_counts()
# Out:
# Brooklyn               141957
# Staten Island           98823
# Bronx                   58780
# New York                49409
# Flushing                22390
# Jamaica                 21825
# Fresh Meadows           10769
# Ridgewood               10347
# Whitestone              10346
# Queens Village           9743
# Bayside                  9538
# Astoria                  7764
# Forest Hills             7714
# Little Neck              6991
# Oakland Gardens          6864
# South Ozone Park         6253
# East Elmhurst            6039
# Rosedale                 6002
# Ozone Park               5827
# Springfield Gardens      5734
# Woodside                 5666
# Middle Village           5151
# Bellerose                4910
# Glen Oaks                4699
# Elmhurst                 4699
# Howard Beach             4418
# Far Rockaway             4336
# Maspeth                  3934
# Jackson Heights          3523
# Rockaway Park            3510
# Corona                   3366
# ...

# %%
tree_subset['boro_ct'].value_counts()
# Out:
# 4089200.0    2394
# 4157101.0    2236
# 4157901.0    2062
# 3070201.0    1901
# 4155102.0    1868
#              ...
# 3016400.0       2
# 4062400.0       1
# 5015601.0       1
# 3121000.0       1
# 2016300.0       1
# Name: boro_ct, Length: 2121, dtype: int64

# %%
tree_subset['zip_city'].fillna('Not specified', inplace = True)
tree_subset['boro_ct'].fillna('Not specified', inplace = True)
# Out:
# C:\Users\leasi\AppData\Local\Temp\ipykernel_38860\3797044370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_subset['zip_city'].fillna('Not specified', inplace = True)
# C:\Users\leasi\AppData\Local\Temp\ipykernel_38860\3797044370.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tree_subset['boro_ct'].fillna('Not specified', inplace = True)

# %%
# Let's lokk if there's any Nan values left 
tree_subset.isna().sum()
# Out:
# OBJECTID      0
# cen_year      0
# tree_dbh      0
# address       0
# tree_loc      0
# pit_type      0
# soil_lvl      0
# status        0
# spc_latin     0
# spc_common    0
# vert_other    0
# vert_pgrd     0
# vert_tgrd     0
# vert_wall     0
# horz_blck     0
# horz_grate    0
# horz_plant    0
# horz_other    0
# sidw_crack    0
# sidw_raise    0
# wire_htap     0
# wire_prime    0
# wire_2nd      0
# wire_other    0
# inf_canopy    0
# inf_guard     0
# inf_wires     0
# inf_paving    0
# inf_outlet    0
# inf_shoes     0
# inf_lights    0
# inf_other     0
# trunk_dmg     0
# zipcode       0
# zip_city      0
# cb_num        0
# boroname      0
# cncldist      0
# st_assem      0
# st_senate     0
# nta           0
# nta_name      0
# boro_ct       0
# latitude      0
# longitude     0
# objectid_1    0
# dtype: int64

# %%
tree_subset.describe()
# Out:
#            OBJECTID       cen_year       tree_dbh        zipcode  \
# count  5.923720e+05  592372.000000  592372.000000  592372.000000
# mean   8.885585e+05    1981.843556      12.833505   10786.219556
# std    1.710032e+05     215.827732      10.316484    1426.047005
# min    5.923730e+05       0.000000      -1.000000       0.000000
# 25%    7.404658e+05    2005.000000       6.000000   10314.000000
# 50%    8.885585e+05    2005.000000      11.000000   11218.000000
# 75%    1.036651e+06    2006.000000      18.000000   11367.000000
# max    1.184744e+06    2006.000000    2100.000000   11697.000000
#
#               cb_num      cncldist       st_assem      st_senate  \
# count  592372.000000  592372.00000  592372.000000  592372.000000
# mean      340.356425      29.33223      47.046567      19.197947
# std       130.634659      15.21075      20.634035       8.128786
# min         0.000000       0.00000       0.000000       0.000000
# ...

# %%
tree_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'OBJECTID'}>,
#         <AxesSubplot:title={'center':'cen_year'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>,
#         <AxesSubplot:title={'center':'zipcode'}>],
#        [<AxesSubplot:title={'center':'cb_num'}>,
#         <AxesSubplot:title={'center':'cncldist'}>,
#         <AxesSubplot:title={'center':'st_assem'}>,
#         <AxesSubplot:title={'center':'st_senate'}>],
#        [<AxesSubplot:title={'center':'boro_ct'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'objectid_1'}>],
#        [<AxesSubplot:title={'center':'census tract'}>,
#         <AxesSubplot:title={'center':'bin'}>,
#         <AxesSubplot:title={'center':'bbl'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# The dbh (diamater) are way to high --> up to 2000 inches
# Let's see how many tree have an abnormaly big diamater

# %%
big_trees = tree_subset[tree_subset['tree_dbh']>50]
big_trees

#Ther's 1921 rows/tree with diamater biger than 50 inches
# Out:
#         OBJECTID  cen_year  tree_dbh                       address tree_loc  \
# 14412     606556      2005        61          202 WEST  137 STREET    Front
# 14413     606557      2005        54          210 WEST  137 STREET    Front
# 16383     608508      2005        52          256 WEST  109 STREET    Front
# 16533     608656      2005        55          160 EAST   84 STREET    Front
# 21034     613120      2005        53  2297 ADAM C POWELL BOULEVARD    Front
# ...          ...       ...       ...                           ...      ...
# 592067   1184438      2005        81          350 RICHMOND TERRACE    Front
# 592068   1184439      2005        65          376 RICHMOND TERRACE    Front
# 592140   1184512      2005        59          240 RICHMOND TERRACE     Side
# 592145   1184517      2005        82          242 RICHMOND TERRACE    Front
# 592201   1184574      2005        70             236 HUNTER AVENUE    Front
#
# ...

# %%
big_trees[['OBJECTID','tree_dbh']].plot(kind='scatter', x='OBJECTID', y='tree_dbh', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='OBJECTID', ylabel='tree_dbh'>

# %% [markdown]
#  --> It seems like the distribituion is not good for the dbh --> To look at later

# %% [markdown]
# The columns where missing values are, are not a problem. We don't need to look at it

# %%
dead = tree_subset[tree_subset['status']=='Dead']
dead
# Out:
#         OBJECTID  cen_year  tree_dbh               address     tree_loc  \
# 135       592504      2005         7  135 RIVINGTON STREET       Across
# 136       592505      2005         2  137 RIVINGTON STREET  Side/Across
# 143       592512      2005         2  137 RIVINGTON STREET  Side/Across
# 224       592592      2005         3         1955 1 AVENUE        Front
# 233       592600      2005         2         1955 1 AVENUE        Front
# ...          ...       ...       ...                   ...          ...
# 592238   1184611      2005         2    777 SEAVIEW AVENUE       Median
# 592243   1184616      2006         2    774 SEAVIEW AVENUE       Median
# 592249   1184622      2006         3    774 SEAVIEW AVENUE       Median
# 592250   1184623      2006         2    768 SEAVIEW AVENUE       Median
# 592258   1184631      2006         5    694 SEAVIEW AVENUE       Median
#
#             pit_type soil_lvl status     spc_latin    spc_common vert_other  \
# ...

# %%
stumps = tree_subset[tree_subset['status']=='Stump']
stumps
# Out:
# Empty DataFrame
# Columns: [OBJECTID, cen_year, tree_dbh, address, tree_loc, pit_type, soil_lvl, status, spc_latin, spc_common, vert_other, vert_pgrd, vert_tgrd, vert_wall, horz_blck, horz_grate, horz_plant, horz_other, sidw_crack, sidw_raise, wire_htap, wire_prime, wire_2nd, wire_other, inf_canopy, inf_guard, inf_wires, inf_paving, inf_outlet, inf_shoes, inf_lights, inf_other, trunk_dmg, zipcode, zip_city, cb_num, boroname, cncldist, st_assem, st_senate, nta, nta_name, boro_ct, latitude, longitude, objectid_1, census tract, bin, bbl, Location 1]
# Index: []

# %%
tree_subset['status'].value_counts()
# according to the pdf explaining the columns there's other values possible for the tree status (7 in total) but only 4 where used by the people
# Out:
# Good         393464
# Excellent    141657
# Poor          49131
# Dead           8120
# Name: status, dtype: int64

# %% [markdown]
# In this dataset (compared to 2015 cencus), when the tree is dead they didn't specified the species (but it's not marked as NaN , ther's a value for it : Unknown Dead) but theys did fill all the other categories that characterized the tree unlike the 2015 census where it's all NaN values when the tree is dead or Stump

# %% [markdown]
# Let's look at the distribution of the yes and no

# %%
tree_subset.columns
# Out:
# Index(['OBJECTID', 'cen_year', 'tree_dbh', 'address', 'tree_loc', 'pit_type',
#        'soil_lvl', 'status', 'spc_latin', 'spc_common', 'vert_other',
#        'vert_pgrd', 'vert_tgrd', 'vert_wall', 'horz_blck', 'horz_grate',
#        'horz_plant', 'horz_other', 'sidw_crack', 'sidw_raise', 'wire_htap',
#        'wire_prime', 'wire_2nd', 'wire_other', 'inf_canopy', 'inf_guard',
#        'inf_wires', 'inf_paving', 'inf_outlet', 'inf_shoes', 'inf_lights',
#        'inf_other', 'trunk_dmg', 'zipcode', 'zip_city', 'cb_num', 'boroname',
#        'cncldist', 'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct',
#        'latitude', 'longitude', 'objectid_1', 'census tract', 'bin', 'bbl',
#        'Location 1'],
#       dtype='object')

# %%
tree_problems = tree_subset[['vert_other',
       'vert_pgrd', 'vert_tgrd', 'vert_wall', 'horz_blck', 'horz_grate',
       'horz_plant', 'horz_other', 'sidw_crack', 'sidw_raise', 'wire_htap',
       'wire_prime', 'wire_2nd', 'wire_other', 'inf_canopy', 'inf_guard',
       'inf_wires', 'inf_paving', 'inf_outlet', 'inf_shoes', 'inf_lights',
       'inf_other']]
tree_problems
# Out:
#        vert_other vert_pgrd vert_tgrd vert_wall horz_blck horz_grate  \
# 0              No        No        No        No        No         No
# 1              No        No        No        No        No         No
# 2              No        No        No        No        No         No
# 3              No        No        No        No        No         No
# 4              No        No        No        No        No         No
# ...           ...       ...       ...       ...       ...        ...
# 592367         No        No        No        No        No         No
# 592368         No        No        No        No        No         No
# 592369         No        No        No        No        No         No
# 592370         No        No        No        No        No         No
# 592371         No        No        No        No        No         No
#
#        horz_plant horz_other sidw_crack sidw_raise wire_htap wire_prime  \
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      vert_other  vert_pgrd  vert_tgrd  vert_wall  horz_blck  horz_grate  \
# No       577543     551262     582511     580187     462809      585164
# Yes       14829      41110       9861      12185     129563        7208
#
#      horz_plant  horz_other  sidw_crack  sidw_raise  wire_htap  wire_prime  \
# No       542926      573035      484166      494244     470959      480121
# Yes       49446       19337      108206       98128     121413      112251
#
#      wire_2nd  wire_other  inf_canopy  inf_guard  inf_wires  inf_paving  \
# No     464949      505614      585068     588500     578604      549532
# Yes    127423       86758        7304       3872      13768       42840
#
#      inf_outlet  inf_shoes  inf_lights  inf_other
# No       590545     591956      589844     563628
# Yes        1827        416        2528      28744

# %%
# We are going, for now, to delete the trees with big dbh and stump diamater
tree_norm_subset = tree_subset[(tree_subset['tree_dbh']<=50)]
tree_norm_subset
# Out:
#         OBJECTID  cen_year  tree_dbh             address tree_loc  \
# 0         592373      2005         6      1139 57 STREET    Front
# 1         592374      2005         6  2220 BERGEN AVENUE   Across
# 2         592375      2005        13  2360 BERGEN AVENUE    Front
# 3         592376      2005        13  2254 BERGEN AVENUE   Across
# 4         592377      2005        15  2332 BERGEN AVENUE   Across
# ...          ...       ...       ...                 ...      ...
# 592367   1184740      2005         9  62 LEWISTON STREET    Front
# 592368   1184741      2005         7  68 LEWISTON STREET    Front
# 592369   1184742      2005         5    69 TRAVIS AVENUE     Side
# 592370   1184743      2005         9    69 TRAVIS AVENUE     Side
# 592371   1184744      2005         2    69 TRAVIS AVENUE     Side
#
#               pit_type soil_lvl status  \
# 0         Sidewalk Pit    Level   Good
# 1         Sidewalk Pit    Level   Good
# 2       Continuous Pit    Level   Good
# ...

# %%
tree_norm_subset[['OBJECTID','tree_dbh']].plot(kind='scatter', x='OBJECTID', y='tree_dbh', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='OBJECTID', ylabel='tree_dbh'>
